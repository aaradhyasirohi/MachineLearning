# %% [markdown]
# <a href="https://colab.research.google.com/github/aaradhyasirohi/MachineLearning/blob/main/split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2f01ed65-b07c-468f-bcec-cf195cd5bbd1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2f01ed65-b07c-468f-bcec-cf195cd5bbd1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("carprices.csv")
df
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6          18000
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35500
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
from matplotlib import colors
plt.scatter(df['Mileage'],df['Sell Price($)'],c='red')

# %%
#from sklearn.linear_model import LinearRegression
#model=LinearRegression()
#model.fit(df[['Mileage']],df['Sell Price($)'])
plt.xlabel('Mileage')
plt.ylabel('Sell Price($)')
plt.scatter(df['Mileage'],df['Sell Price($)'],c='red')
plt.title('Regression1')
plt.show()

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'],c='red')
plt.xlabel('Age(yrs)')
plt.ylabel('Sell Price($)')
plt.title('Regression2')
plt.show()

# %%
x=df[['Mileage','Age(yrs)']]
y=df['Sell Price($)']
x
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)# random_state=10 means train data would not be changed

# %%
len(x_train)
#len(x_test)
# Out:
# 16

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([28321.65335184, 15689.95019455, 24496.38770959, 30003.96459686])

# %%
model.score(x_test,y_test)
# Out:
# 0.9054512940381392
